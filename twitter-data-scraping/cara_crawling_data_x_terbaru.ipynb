# %% [markdown]
# # ***CRAWLING DATA X TERBARU KEYWORD : CHINDO***

# %% [markdown]
# kct65342@nezid.com    052209298a800ce5975f5d210a0cfc852ba1010a

# %%
# !pip install pandas
# !curl -sL https://deb.nodesource.com/setup_18.x | sudo -E bash -
# !sudo apt-get install -y nodejs
# Out:
# ...
# 2024-02-29 05:15:21 - Installing pre-requisites
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,796 kB]
# Get:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [1,927 kB]
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     127   )
#     128   if ephemeral:
# --> 129     _message.blocking_request(
#     130         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %%
import os

os.chdir('/content/drive/MyDrive/Colab_Notebooks')

# %%
data = 'data_@RTErdogan.csv'
search_keyword = 'terörü lanetliyorum until:2023-12-11 since:2020-11-01'
limit = 30

# !npx --yes tweet-harvest@2.2.8 -o "{data}" -s "{search_keyword}" -l {limit} --token "59381974fca4d922c67d75022dfb2aaffc8d6437"
#!npx --yes tweet-harvest@2.2.8 -o "output.csv" -s "to:@RTErdogan" -l {limit} --token "a99701111d5f71e4193201373cde89b21d20854e"

#!npx --yes tweet-harvest@2.2.8 -o "{data}" -s "from:@HusnuOsman71073" -l {limit} --token "a99701111d5f71e4193201373cde89b21d20854e"
# Out:
# ERROR: You must supply a command.
#
# Execute binaries from npm packages.
#
#   npx [options] <command>[@version] [command-arg]...
#
#   npx [options] [-p|--package <package>]... <command> [command-arg]...
#
#   npx [options] -c '<command-string>'
#
#   npx --shell-auto-fallback [shell]
#
#
# Options:
#   --package, -p          Package to be installed.                       [string]
#   --cache                Location of the npm cache.                     [string]
#   --always-spawn         Always spawn a child process to execute the command.
#                                                                        [boolean]
#   --no-install           Skip installation if a package is missing.    [boolean]
#   --userconfig           Path to user npmrc.                            [string]
#   --call, -c             Execute string as if inside `npm run-script`.  [string]
#   --shell, -s            Shell to execute the command with, if any.
# ...

# %%
data = 'data_@RTErdogan.csv'
search_keyword = 'terörü lanetliyorum until:2023-12-11 since:2020-11-01'
limit = 30

# !npx --yes tweet-harvest@2.2.8 -o "output.csv" -s "to:@RTErdogan" -l {limit} --token "a99701111d5f71e4193201373cde89b21d20854e"   #hashtag bazlı arama

# %%
# !npx --yes tweet-harvest@2.2.8 -o "{data}" -s "from:@HusnuOsman71073" -l {limit} --token "a99701111d5f71e4193201373cde89b21d20854e"  #kulllanıcı bazlı arama

# %%
import pandas as pd

# Veri setini yükle
data = pd.read_csv("/content/tweets-data/output.csv", sep=";")

# Veri seti hakkında bilgi edin
data.info()

# %%
data.shape

# %%
# İlk beş kaydı görüntüle
data.head(50)

# %%
data.columns

# %%
import pandas as pd

data = pd.read_csv("/content/tweets-data/data_chindo.csv", sep=";")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           57 non-null     object
#  1   id_str               57 non-null     int64
#  2   full_text            57 non-null     object
#  3   quote_count          57 non-null     int64
#  4   reply_count          57 non-null     int64
#  5   retweet_count        57 non-null     int64
#  6   favorite_count       57 non-null     int64
#  7   lang                 57 non-null     object
#  8   user_id_str          57 non-null     int64
#  9   conversation_id_str  57 non-null     int64
#  10  username             57 non-null     object
#  11  tweet_url            57 non-null     object
# dtypes: int64(7), object(5)
# memory usage: 5.5+ KB

# %%
data.head(5)
# Out:
#                        created_at               id_str  \
# 0  Sun Dec 10 23:59:50 +0000 2023  1733999998151647524
# 1  Sun Dec 10 23:59:45 +0000 2023  1733999979549892989
# 2  Sun Dec 10 23:59:27 +0000 2023  1733999900776624499
# 3  Sun Dec 10 23:59:21 +0000 2023  1733999876428738947
# 4  Sun Dec 10 23:59:07 +0000 2023  1733999817528168803
#
#                                            full_text  quote_count  \
# 0  @ganjarpranowo Sebagai pemimpin yang bisa kita...            0
# 1  Dukungan buruh membawa dampak elektoral yang c...            0
# 2  Anies menguat, Ganjar sebenarnya diinginkan, t...            0
# 3  @kompascom Loh, loh, loh ganjar urutan ke tiga...            0
# 4  1. Anies - Amin 2. Prabowo - Gibran 3. Ganjar ...            0
#
#    reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0            0              0               0   in  1704535898069639169
# 1            0              0               2   in           2495508415
# ...
